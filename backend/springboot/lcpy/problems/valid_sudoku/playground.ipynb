# %%
from helpers import run_is_valid_sudoku, assert_is_valid_sudoku
from solution import Solution

# %%
# Example test case
board = [['5','3','.','.','7','.','.','.','.'],['6','.','.','1','9','5','.','.','.'],['.','9','8','.','.','.','.','6','.'],['8','.','.','.','6','.','.','.','3'],['4','.','.','8','.','3','.','.','1'],['7','.','.','.','2','.','.','.','6'],['.','6','.','.','.','.','2','8','.'],['.','.','.','4','1','9','.','.','5'],['.','.','.','.','.','.','.','7','9']]
expected = True

# %%
result = run_is_valid_sudoku(Solution, board)
result

# %%
assert_is_valid_sudoku(result, expected)
