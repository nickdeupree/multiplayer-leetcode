# %%
from helpers import run_coin_change, assert_coin_change
from solution import Solution

# %%
# Example test case
coins = [1, 2, 5]
amount = 11
expected = 3

# %%
result = run_coin_change(Solution, coins, amount)
result

# %%
assert_coin_change(result, expected)
