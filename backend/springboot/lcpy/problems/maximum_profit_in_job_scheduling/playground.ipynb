# %%
from helpers import run_job_scheduling, assert_job_scheduling
from solution import Solution

# %%
# Example test case
start_time = [1, 2, 3, 3]
end_time = [3, 4, 5, 6]
profit = [50, 10, 40, 70]
expected = 120

# %%
result = run_job_scheduling(Solution, start_time, end_time, profit)
result

# %%
assert_job_scheduling(result, expected)
