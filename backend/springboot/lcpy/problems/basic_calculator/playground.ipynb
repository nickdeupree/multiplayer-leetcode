# %%
from helpers import run_calculate, assert_calculate
from solution import Solution

# %%
# Example test case
s = '(1+(4+5+2)-3)+(6+8)'
expected = 23

# %%
result = run_calculate(Solution, s)
result

# %%
assert_calculate(result, expected)
