# %%
from helpers import run_is_anagram, assert_is_anagram
from solution import Solution

# %%
# Example test case
s = 'anagram'
t = 'nagaram'
expected = True

# %%
result = run_is_anagram(Solution, s, t)
result

# %%
assert_is_anagram(result, expected)
