# %%
from helpers import run_partition, assert_partition
from solution import Solution

# %%
# Example test case
s = 'aab'
expected = [['a', 'a', 'b'], ['aa', 'b']]

# %%
result = run_partition(Solution, s)
result

# %%
assert_partition(result, expected)
