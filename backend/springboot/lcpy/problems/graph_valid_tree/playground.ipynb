# %%
from helpers import run_valid_tree, assert_valid_tree
from solution import Solution

# %%
# Example test case
n = 5
edges = [[0,1], [0,2], [0,3], [1,4]]
expected = True

# %%
result = run_valid_tree(Solution, n, edges)
result

# %%
assert_valid_tree(result, expected)
