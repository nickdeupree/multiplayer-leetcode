# %%
from helpers import run_my_atoi, assert_my_atoi
from solution import Solution

# %%
# Example test case
s = '42'
expected = 42

# %%
result = run_my_atoi(Solution, s)
result

# %%
assert_my_atoi(result, expected)
