# %%
from helpers import run_unique_paths, assert_unique_paths
from solution import Solution

# %%
# Example test case
m = 3
n = 7
expected = 28

# %%
result = run_unique_paths(Solution, m, n)
result

# %%
assert_unique_paths(result, expected)
