# %%
from helpers import run_can_complete_circuit, assert_can_complete_circuit
from solution import Solution

# %%
# Example test case
gas = [1,2,3,4,5]
cost = [3,4,5,1,2]
expected = 3

# %%
result = run_can_complete_circuit(Solution, gas, cost)
result

# %%
assert_can_complete_circuit(result, expected)
