# %%
from helpers import run_k_closest, assert_k_closest
from solution import Solution

# %%
# Example test case
points = [[1, 3], [-2, 2]]
k = 1
expected = [[-2, 2]]

# %%
result = run_k_closest(Solution, points, k)
result

# %%
assert_k_closest(result, expected)
