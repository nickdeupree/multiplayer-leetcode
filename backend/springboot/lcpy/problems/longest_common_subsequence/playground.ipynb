# %%
from helpers import run_longest_common_subsequence, assert_longest_common_subsequence
from solution import Solution

# %%
# Example test case
text1 = 'abcde'
text2 = 'ace'
expected = 3

# %%
result = run_longest_common_subsequence(Solution, text1, text2)
result

# %%
assert_longest_common_subsequence(result, expected)
