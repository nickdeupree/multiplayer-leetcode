# %%
from helpers import run_rotate, assert_rotate
from solution import Solution

# %%
# Example test case
nums = [1, 2, 3, 4, 5, 6, 7]
k = 3
expected = [5, 6, 7, 1, 2, 3, 4]

# %%
result = run_rotate(Solution, nums, k)
result

# %%
assert_rotate(result, expected)
