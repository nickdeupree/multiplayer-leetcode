# %%
from helpers import run_num_decodings, assert_num_decodings
from solution import Solution

# %%
# Example test case
s = '226'
expected = 3

# %%
result = run_num_decodings(Solution, s)
result

# %%
assert_num_decodings(result, expected)
