# %%
from helpers import run_top_k_frequent, assert_top_k_frequent
from solution import Solution

# %%
# Example test case
nums = [1, 1, 1, 2, 2, 3]
k = 2
expected = [1, 2]

# %%
result = run_top_k_frequent(Solution, nums, k)
result

# %%
assert_top_k_frequent(result, expected)
