# %%
from helpers import run_find_anagrams, assert_find_anagrams
from solution import Solution

# %%
# Example test case
s = 'cbaebabacd'
p = 'abc'
expected = [0, 6]

# %%
result = run_find_anagrams(Solution, s, p)
result

# %%
assert_find_anagrams(result, expected)
