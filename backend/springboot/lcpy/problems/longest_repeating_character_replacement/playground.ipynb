# %%
from helpers import run_character_replacement, assert_character_replacement
from solution import Solution

# %%
# Example test case
s = 'ABAB'
k = 2
expected = 4

# %%
result = run_character_replacement(Solution, s, k)
result

# %%
assert_character_replacement(result, expected)
