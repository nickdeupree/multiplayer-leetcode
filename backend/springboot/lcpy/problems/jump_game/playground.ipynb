# %%
from helpers import run_can_jump, assert_can_jump
from solution import Solution

# %%
# Example test case
nums = [2, 3, 1, 1, 4]
expected = True

# %%
result = run_can_jump(Solution, nums)
result

# %%
assert_can_jump(result, expected)
