# %%
from helpers import run_count_components, assert_count_components
from solution import Solution

# %%
# Example test case
n = 5
edges = [[0, 1], [1, 2], [3, 4]]
expected = 2

# %%
result = run_count_components(Solution, n, edges)
result

# %%
assert_count_components(result, expected)
