# %%
from helpers import run_exist, assert_exist
from solution import Solution

# %%
# Example test case
board = [['A', 'B', 'C', 'E'], ['S', 'F', 'C', 'S'], ['A', 'D', 'E', 'E']]
word = 'ABCCED'
expected = True

# %%
result = run_exist(Solution, board, word)
result

# %%
assert_exist(result, expected)
