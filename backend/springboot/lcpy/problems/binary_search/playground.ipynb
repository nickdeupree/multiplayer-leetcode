# %%
from helpers import run_search, assert_search
from solution import Solution

# %%
# Example test case
nums = [-1, 0, 3, 5, 9, 12]
target = 9
expected = 4

# %%
result = run_search(Solution, nums, target)
result

# %%
assert_search(result, expected)
