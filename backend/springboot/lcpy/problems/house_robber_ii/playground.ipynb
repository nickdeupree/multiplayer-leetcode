# %%
from helpers import run_rob, assert_rob
from solution import Solution

# %%
# Example test case
nums = [2, 3, 2]
expected = 3

# %%
result = run_rob(Solution, nums)
result

# %%
assert_rob(result, expected)
