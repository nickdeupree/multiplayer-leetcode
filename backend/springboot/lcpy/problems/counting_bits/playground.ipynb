# %%
from helpers import run_count_bits, assert_count_bits
from solution import Solution

# %%
# Example test case
n = 2
expected = [0, 1, 1]

# %%
result = run_count_bits(Solution, n)
result

# %%
assert_count_bits(result, expected)
